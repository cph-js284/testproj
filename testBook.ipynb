# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Alist = np.arange(1,100)

# %%
plt.plot(Alist,Alist, "r--")

# %%
Blist = np.arange(1,100)
plt.plot(Blist,Blist, "b--")
